# %% [markdown]
# # Analyse de données d'une librairie en ligne

# %% [markdown]
# ### Table des matiéres
#
# * [Objectifs](#Intro)
# * [A. Import des données](#chapitre1)
#     * [1. Customers](#petit1)
#     * [2. Products](#petit2)
#     * [3. Transactions](#petit3)
# * [B. Nettoyage et préparation des données](#chapitre2)
#     * [1. Nettoyage du ficher customers](#petit4)
#         * [a)information](#tit1)
#         * [b)Verification de la presence de doublon](#tit2)
#         * [c)Creation de la ligne age]((#tit3)
#     * [2. Nettoyage du ficher products ](#petit5)
#         * [a)information](#tit4)
#         * [b)Verification de la presence de doublon](#tit5)
#         * [c)Identification d'un prix negatif](#tit6)
#     * [3. Nettoyage du ficher transactions ](#petit6)
#         * [a)information](#tit7)
#         * [b)Verification de la presence de doublon](#tit8)
#         * [c)Elimination des valeurs test(prix negatifs)](#tit10)
# * [C. Jointure](#chapitre3)
#     * [1. merge des tables transactions et products](#petit7)
#     * [2. idendification de produits non achetés](#petit8)
#     * [3. merge des tables produits vendu et customers](#petit9)
#     * [4.Identification de cliens sans achats](#petit10)
# * [ D. Analyse des données](#chapitre4)
#     * [1. Identification de produits sans prix](#petit11)
#     * [2. Identification de clients pro](#petit12)
#     * [3. Etude temporel ](#petit13)
#     * [4. Observation du prix des produits par categorie  ](#petit14)
#     * [5. Calcule du chiffre d'affaire ](#petit15)
#         * [a) chiffre d'affaire avec les pro](#tit11)
#         * [b) chiffre d'affaire sans les pro](#tit12)
#         * [c) chiffre d'affaire par produit](#tit13)
#     * [6. Recherche et identification d'outliers ](#petit16)
#     * [6. Groupe](#petit17)

# %% [markdown]
# # Objectif <a class="anchor" id="Intro"></a>

# %% [markdown]
#     Le but de ce notebook est d'avoir une meilleure connaissance des données recolté par la librairie en ligne et d'avoir une vision globale des commandes, des produits vendus mais aussi des clients et de leurs préférences d'achat.

# %% [markdown]
# ## A. Import des données <a class="anchor" id="chapitre1"></a>

# %% [markdown]
# Librairie utilisé pour le notebook

# %%
import pymysql
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from datetime import date

# %% [markdown]
# Fonction utilisé pour changer une serie en dataframe pour pourvoir les utilisées pour des graphique.

# %%
def todataframe(nom):
    #le mettre en dataframe (et plus en serie)
    nom = nom.to_frame()
    # ajouté un index
    nom = nom.reset_index()
    return nom

# %% [markdown]
# Dans un premier temps nous avons crée une base de donnée sur MySQL workbench. Nous avons crée une table par document puis importé sur le jupiter. La ligne de code ci-dessous nous permet de connecté notre base de donnée à notre jupyter.

# %%
conn=pymysql.connect(host='localhost',port=int(3306),user='root',passwd='groot',db='librairie_en_ligne')

# %% [markdown]
# ### 1) Customers <a class="anchor" id="petit1"></a>

# %%
customers=pd.read_sql_query("SELECT * FROM customers " ,conn)
customers
# Out:
#      client_id sex  birth
# 0       c_4410   f   1967
# 1       c_7839   f   1975
# 2       c_1699   f   1984
# 3       c_5961   f   1962
# 4       c_5320   m   1943
# ...        ...  ..    ...
# 8618    c_7920   m   1956
# 8619    c_7403   f   1970
# 8620    c_5119   m   1974
# 8621    c_5643   f   1968
# 8622      c_84   f   1982
#
# [8623 rows x 3 columns]

# %% [markdown]
# ### 2) Products <a class="anchor" id="petit2"></a>

# %%
products=pd.read_sql_query("SELECT * FROM products " ,conn)
products
# Out:
#      id_prod   price  categ
# 0     0_1421   19.99      0
# 1     0_1368    5.13      0
# 2      0_731   17.99      0
# 3      1_587    4.99      1
# 4     0_1507    3.99      0
# ...      ...     ...    ...
# 3282    2_23  115.99      2
# 3283   0_146   17.14      0
# 3284   0_802   11.22      0
# 3285   1_140   38.56      1
# 3286  0_1920   25.16      0
#
# [3287 rows x 3 columns]

# %% [markdown]
# ### 3) Transactions <a class="anchor" id="petit3"></a>

# %%
transactions=pd.read_sql_query("SELECT * FROM transactions " ,conn)
transactions
# Out:
#        id_prod                        date session_id client_id
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                         ...        ...       ...
# 337011   1_671  2021-05-28 12:35:46.214839    s_40720    c_3454
# 337012   0_759  2021-06-19 00:19:23.917703    s_50568    c_6268
# 337013  0_1256  2021-03-16 17:31:59.442007     s_7219    c_4137
# 337014   2_227  2021-10-30 16:50:15.997750   s_112349       c_5
# 337015  0_1417  2021-06-26 14:38:19.732946    s_54117    c_6714
#
# [337016 rows x 4 columns]

# %% [markdown]
# ## B. Nettoyage et préparation des données                  <a class="anchor" id="chapitre2"></a>

# %% [markdown]
# ### 1) Nettoyage du ficher customers <a class="anchor" id="petit4"></a>

# %% [markdown]
# #### a) Information  <a class="anchor" id="tit1"></a>

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8623 entries, 0 to 8622
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  8623 non-null   object
#  1   sex        8623 non-null   object
#  2   birth      8623 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 202.2+ KB

# %% [markdown]
# Le fichier customers posséde 3 colonnes et 8623 lignes et il n'y a pas de valeur NaN ou valeur manquante.

# %% [markdown]
# #### b) Verification de la presence de doublon <a class="anchor" id="tit2"></a>

# %%
customers.duplicated(['client_id']).value_counts()
# Out:
# False    8623
# dtype: int64

# %% [markdown]
# Nous avons utilisé la fonction duplicated() pour identifié s'il y avait la presence de valeur double, ce qui n'est pas le cas. Nous avons choisi de tester la colonne client_id car elle nous permettra de joindre la table customers à la table transaction.
# Nous avons voulut verifié que la colonne sex etait bien constitué uniquement de femme et d'homme.

# %%
femme = customers.sex.loc[customers.sex  == "f"].count()
homme =customers.sex.loc[customers.sex  == "m"].count()
[femme,homme]
# Out:
# [4491, 4132]

# %%
femme+homme
# Out:
# 8623

# %%
customers['birth'].min()
# Out:
# 1929

# %%
customers['birth'].max()
# Out:
# 2004

# %% [markdown]
# Les clients les plus vieux sont nées en 1929 et les plus jeunes en 2004. Nous avons calculé l'age des clients et ajouté dans une nouvelle colonne Age.

# %% [markdown]
# #### c) Creation d'une colonne age <a class="anchor" id="tit3"></a>

# %%
def calculateAge(birthDate):
    today = date.today()
    age = today.year - birthDate
 
    return age

# %% [markdown]
# cette fonction nous permet de calculer l'age des clients en fonction de la date du jours.

# %%
customers['Age'] = (calculateAge(customers['birth']))
customers
# Out:
#      client_id sex  birth  Age
# 0       c_4410   f   1967   55
# 1       c_7839   f   1975   47
# 2       c_1699   f   1984   38
# 3       c_5961   f   1962   60
# 4       c_5320   m   1943   79
# ...        ...  ..    ...  ...
# 8618    c_7920   m   1956   66
# 8619    c_7403   f   1970   52
# 8620    c_5119   m   1974   48
# 8621    c_5643   f   1968   54
# 8622      c_84   f   1982   40
#
# [8623 rows x 4 columns]

# %%
customers['Age'].describe()
# Out:
# count    8623.000000
# mean       43.719123
# std        16.919535
# min        18.000000
# 25%        30.000000
# 50%        43.000000
# 75%        56.000000
# max        93.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### 2) Nettoyage du ficher products  <a class="anchor" id="petit5"></a>

# %% [markdown]
# #### a) Information <a class="anchor" id="petit5"></a>

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id_prod  3287 non-null   object
#  1   price    3287 non-null   float64
#  2   categ    3287 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 77.2+ KB

# %% [markdown]
# Le fichier products posséde lui aussi 3 colonnes et cette fois ci 3287 lignes. Comme pour le fichier précedent, il n'y a pas de valeur NaN ou valeur manquante.

# %% [markdown]
# #### b)Verification de la presence de doublon <a class="anchor" id="tit5"></a>

# %%
products.duplicated(['id_prod']).value_counts()
# Out:
# False    3287
# dtype: int64

# %% [markdown]
# La colonne Id_prod ne contient que des valeurs unique. Cette colonne nous serviras pour joindre la table products à la table transactions.

# %% [markdown]
# #### c)Identification d'un prix négatif  <a class="anchor" id="tit6"></a>

# %%
products['price'].describe()
# Out:
# count    3287.000000
# mean       21.856641
# std        29.847908
# min        -1.000000
# 25%         6.990000
# 50%        13.060000
# 75%        22.990000
# max       300.000000
# Name: price, dtype: float64

# %% [markdown]
# Nous avons utilisé la fonction describe pour observer les valeurs de la colonne des prix. On peut observé une valeur aberante. La valeur minimal de prix est -1.

# %%
negatif = products.loc[products['price']<=0]
negatif
# Out:
#     id_prod  price  categ
# 731     T_0   -1.0      0

# %% [markdown]
# Cette valeur aberante ne concerne que le produit T_0 et ne posséde pas de categorie.

# %% [markdown]
# ### 3) Nettoyage du ficher transaction <a class="anchor" id="petit6"></a>

# %% [markdown]
# #### a) information <a class="anchor" id="tit7"></a>

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337016 entries, 0 to 337015
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id_prod     337016 non-null  object
#  1   date        337016 non-null  object
#  2   session_id  337016 non-null  object
#  3   client_id   337016 non-null  object
# dtypes: object(4)
# memory usage: 10.3+ MB

# %% [markdown]
# Le fichier Transactions posséde 4 colonnes et 337016 lignes. Comme pour les fichiers précedent, il n'y a pas de valeur NaN ou valeur manquante.

# %% [markdown]
# ####  b)Verification de la presence de doublon <a class="anchor" id="tit8"></a>

# %%
transactions.duplicated(['id_prod']).value_counts()
# Out:
# True     333750
# False      3266
# dtype: int64

# %%
transactions.duplicated(['client_id']).value_counts()
# Out:
# True     328414
# False      8602
# dtype: int64

# %% [markdown]
# Nous pouvons observé la presence de valeur dupliqué dans les colonnes id_prod et client_id. Il est cependant normal que cela arrive, en effet un client a pu acheté plusieurs produits et un produit a pu etre acheté par plusieurs clients.

# %% [markdown]
# #### c) Elimination des valeurs test(prix negatifs) <a class="anchor" id="tit10"></a>

# %% [markdown]
#  Nous nous sommes pour un premier temps concentré sur les produits T_0 qui possédent un prix negatif.

# %%
neg = transactions.loc[transactions['id_prod'] == 'T_0']
neg
# Out:
#        id_prod                             date session_id client_id
# 1431       T_0  test_2021-03-01 02:30:02.237420        s_0      ct_1
# 2365       T_0  test_2021-03-01 02:30:02.237446        s_0      ct_1
# 2895       T_0  test_2021-03-01 02:30:02.237414        s_0      ct_1
# 5955       T_0  test_2021-03-01 02:30:02.237441        s_0      ct_0
# 7283       T_0  test_2021-03-01 02:30:02.237434        s_0      ct_1
# ...        ...                              ...        ...       ...
# 332594     T_0  test_2021-03-01 02:30:02.237445        s_0      ct_0
# 332705     T_0  test_2021-03-01 02:30:02.237423        s_0      ct_1
# 332730     T_0  test_2021-03-01 02:30:02.237421        s_0      ct_1
# 333442     T_0  test_2021-03-01 02:30:02.237431        s_0      ct_1
# 335279     T_0  test_2021-03-01 02:30:02.237430        s_0      ct_0
#
# [200 rows x 4 columns]

# %% [markdown]
# On peut observé que ce sont des transactions test.

# %%
client_test1 = customers.loc[customers['client_id'] == 'ct_1']
client_test1
# Out:
#      client_id sex  birth  Age
# 8494      ct_1   m   2001   21

# %%
client_test2 = customers.loc[customers['client_id'] == 'ct_0']
client_test2
# Out:
#      client_id sex  birth  Age
# 2735      ct_0   f   2001   21

# %% [markdown]
# Il faut supprimer les client ct_0 et ct_1 et les les produits T_0.

# %%
transaction=transactions.loc[transactions['id_prod'] != 'T_0']
transaction
# Out:
#        id_prod                        date session_id client_id
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                         ...        ...       ...
# 337011   1_671  2021-05-28 12:35:46.214839    s_40720    c_3454
# 337012   0_759  2021-06-19 00:19:23.917703    s_50568    c_6268
# 337013  0_1256  2021-03-16 17:31:59.442007     s_7219    c_4137
# 337014   2_227  2021-10-30 16:50:15.997750   s_112349       c_5
# 337015  0_1417  2021-06-26 14:38:19.732946    s_54117    c_6714
#
# [336816 rows x 4 columns]

# %%
product=products.loc[products['id_prod'] != 'T_0']
product
# Out:
#      id_prod   price  categ
# 0     0_1421   19.99      0
# 1     0_1368    5.13      0
# 2      0_731   17.99      0
# 3      1_587    4.99      1
# 4     0_1507    3.99      0
# ...      ...     ...    ...
# 3282    2_23  115.99      2
# 3283   0_146   17.14      0
# 3284   0_802   11.22      0
# 3285   1_140   38.56      1
# 3286  0_1920   25.16      0
#
# [3286 rows x 3 columns]

# %%
customer=customers.loc[(customers['client_id'] != 'ct_0') & (customers['client_id'] != 'ct_1')]
customer
# Out:
#      client_id sex  birth  Age
# 0       c_4410   f   1967   55
# 1       c_7839   f   1975   47
# 2       c_1699   f   1984   38
# 3       c_5961   f   1962   60
# 4       c_5320   m   1943   79
# ...        ...  ..    ...  ...
# 8618    c_7920   m   1956   66
# 8619    c_7403   f   1970   52
# 8620    c_5119   m   1974   48
# 8621    c_5643   f   1968   54
# 8622      c_84   f   1982   40
#
# [8621 rows x 4 columns]

# %% [markdown]
# ## C. jointure <a class="anchor" id="chapitre3"></a>

# %% [markdown]
# Nous avons donc d'abord joint la table transaction avec la table products.

# %% [markdown]
# ### 1. Merge des tables transactions et products <a class="anchor" id="petit7"></a>

# %% [markdown]
# Nous avons joint les deux tables en utilisant un merge python.

# %%
table = pd.merge(transaction, product, on='id_prod', how='outer',indicator=True)
table
# Out:
#        id_prod                        date session_id client_id   price  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450    4.99
# 1       0_1483  2021-10-18 19:16:14.767807   s_106741    c_1576    4.99
# 2       0_1483  2021-11-14 11:11:45.276771   s_119491     c_182    4.99
# 3       0_1483  2021-07-30 19:37:16.087057    s_69222    c_1196    4.99
# 4       0_1483  2021-03-30 14:18:13.403218    s_13545    c_2890    4.99
# ...        ...                         ...        ...       ...     ...
# 336833   0_525                         NaN        NaN       NaN    2.99
# 336834    2_86                         NaN        NaN       NaN  132.36
# 336835   0_299                         NaN        NaN       NaN   22.99
# 336836   0_510                         NaN        NaN       NaN   23.66
# 336837  0_2308                         NaN        NaN       NaN   20.28
#
#         categ      _merge
# 0         0.0        both
# 1         0.0        both
# 2         0.0        both
# 3         0.0        both
# 4         0.0        both
# ...       ...         ...
# 336833    0.0  right_only
# 336834    2.0  right_only
# 336835    0.0  right_only
# 336836    0.0  right_only
# 336837    0.0  right_only
#
# [336838 rows x 7 columns]

# %% [markdown]
# Pour le faire en sql:

# %%
jointure_squl= pd.read_sql_query("SELECT *FROM transactions LEFT JOIN products ON transactions.id_prod = products.id_prod " ,conn)
jointure_squl
# Out:
#        id_prod                        date session_id client_id id_prod  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450  0_1483
# 1        2_226  2022-02-03 01:55:53.276402   s_159142     c_277   2_226
# 2        1_374  2021-09-23 15:13:46.938559    s_94290    c_4270   1_374
# 3       0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597  0_2186
# 4       0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242  0_1351
# ...        ...                         ...        ...       ...     ...
# 337011   1_671  2021-05-28 12:35:46.214839    s_40720    c_3454   1_671
# 337012   0_759  2021-06-19 00:19:23.917703    s_50568    c_6268   0_759
# 337013  0_1256  2021-03-16 17:31:59.442007     s_7219    c_4137  0_1256
# 337014   2_227  2021-10-30 16:50:15.997750   s_112349       c_5   2_227
# 337015  0_1417  2021-06-26 14:38:19.732946    s_54117    c_6714  0_1417
#
#         price  categ
# 0        4.99    0.0
# 1       65.75    2.0
# 2       10.71    1.0
# 3        4.20    0.0
# 4        8.99    0.0
# ...       ...    ...
# 337011  31.99    1.0
# 337012  22.99    0.0
# 337013  11.03    0.0
# 337014  50.99    2.0
# 337015  17.99    0.0
#
# [337016 rows x 7 columns]

# %% [markdown]
# Nous n'avons pas utilisé la jointure SQL mais celle par python comme nous avions commencé a travaillé et nettoyé les données avec python.

# %% [markdown]
# ### 2. idendification de produits non achetés <a class="anchor" id="petit8"></a>

# %% [markdown]
# Certains produits ont n'ont pas de client_id, date ou session_id associé. ces produits n'ont donc pas été acheté.

# %%
table['client_id'].isnull().sum()
# Out:
# 22

# %% [markdown]
# 22 produits sont concernées. Nous les avons séparer dans un df séparé.

# %%
Produit_non_vendu=table.loc[(table['_merge'] == 'right_only')]
Produit_non_vendu
# Out:
#        id_prod date session_id client_id   price  categ      _merge
# 336816  0_1016  NaN        NaN       NaN   35.06    0.0  right_only
# 336817  0_1780  NaN        NaN       NaN    1.67    0.0  right_only
# 336818  0_1062  NaN        NaN       NaN   20.08    0.0  right_only
# 336819  0_1119  NaN        NaN       NaN    2.99    0.0  right_only
# 336820  0_1014  NaN        NaN       NaN    1.15    0.0  right_only
# 336821     1_0  NaN        NaN       NaN   31.82    1.0  right_only
# 336822  0_1318  NaN        NaN       NaN   20.92    0.0  right_only
# 336823  0_1800  NaN        NaN       NaN   22.05    0.0  right_only
# 336824  0_1645  NaN        NaN       NaN    2.99    0.0  right_only
# 336825   0_322  NaN        NaN       NaN    2.99    0.0  right_only
# 336826  0_1620  NaN        NaN       NaN    0.80    0.0  right_only
# 336827  0_1025  NaN        NaN       NaN   24.99    0.0  right_only
# 336828    2_87  NaN        NaN       NaN  220.99    2.0  right_only
# 336829   1_394  NaN        NaN       NaN   39.73    1.0  right_only
# 336830    2_72  NaN        NaN       NaN  141.32    2.0  right_only
# 336831   0_310  NaN        NaN       NaN    1.94    0.0  right_only
# 336832  0_1624  NaN        NaN       NaN   24.50    0.0  right_only
# 336833   0_525  NaN        NaN       NaN    2.99    0.0  right_only
# 336834    2_86  NaN        NaN       NaN  132.36    2.0  right_only
# 336835   0_299  NaN        NaN       NaN   22.99    0.0  right_only
# 336836   0_510  NaN        NaN       NaN   23.66    0.0  right_only
# 336837  0_2308  NaN        NaN       NaN   20.28    0.0  right_only

# %% [markdown]
# Pour analysé les produits non acheté nous les avons groupé par categorie.

# %%
non_vendu = Produit_non_vendu['price'].groupby(Produit_non_vendu['categ']).describe()
non_vendu
# Out:
#        count     mean        std     min       25%      50%       75%     max
# categ
# 0.0     17.0   13.650  11.611998    0.80    2.9900   20.080   22.9900   35.06
# 1.0      2.0   35.775   5.593215   31.82   33.7975   35.775   37.7525   39.73
# 2.0      3.0  164.890  48.790141  132.36  136.8400  141.320  181.1550  220.99

# %% [markdown]
# 17 produits appartiennent a la premiere categorie.

# %%
sns.boxplot(data=Produit_non_vendu, x="categ", y="price", palette = "Set1")
# Out:
# <AxesSubplot:xlabel='categ', ylabel='price'>

# %% [markdown]
# ### 3. merge des tables produits vendu et customers <a class="anchor" id="petit9"></a>

# %% [markdown]
# Nous avons recupéré tout les produits vendu et nous avons verifié que la table ne contenait pas de valeur nul avant de realisé la jointure avec la table customer.

# %%
Produit_vendu=table.loc[(table['_merge'] != 'right_only')]
Produit_vendu['client_id'].isnull().sum()
# Out:
# 0

# %%
tables = pd.merge(Produit_vendu, customer, on='client_id', how='outer')
tables
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450   4.99    0.0
# 1       0_1085  2021-09-29 11:14:59.793823    s_97382    c_4450   3.99    0.0
# 2       0_1453  2021-08-27 19:50:46.796939    s_81509    c_4450   7.99    0.0
# 3       0_1405  2021-08-27 20:07:25.878440    s_81509    c_4450   4.99    0.0
# 4       0_1392  2021-12-28 11:45:04.072281   s_141302    c_4450   6.30    0.0
# ...        ...                         ...        ...       ...    ...    ...
# 336832     NaN                         NaN        NaN     c_862    NaN    NaN
# 336833     NaN                         NaN        NaN    c_7584    NaN    NaN
# 336834     NaN                         NaN        NaN      c_90    NaN    NaN
# 336835     NaN                         NaN        NaN     c_587    NaN    NaN
# 336836     NaN                         NaN        NaN    c_3526    NaN    NaN
#
#        _merge sex  birth  Age
# 0        both   f   1977   45
# 1        both   f   1977   45
# 2        both   f   1977   45
# 3        both   f   1977   45
# 4        both   f   1977   45
# ...       ...  ..    ...  ...
# 336832    NaN   f   1956   66
# 336833    NaN   f   1960   62
# 336834    NaN   m   2001   21
# 336835    NaN   m   1993   29
# 336836    NaN   m   1956   66
#
# [336837 rows x 10 columns]

# %% [markdown]
# Nous avons pu observé que certaint  clients n'ont pas acheté de produit.

# %% [markdown]
# ### 4.Identification de cliens sans achats <a class="anchor" id="petit10"></a>

# %%
client_sans_achat = tables[tables['id_prod'].isnull()]
client_sans_achat.shape
# Out:
# (21, 10)

# %% [markdown]
# 21 clients n'ont pas acheté de produit.

# %%
sans_achat= client_sans_achat[['client_id','sex','Age']]
sans_achat
# Out:
#        client_id sex  Age
# 336816    c_8253   f   21
# 336817    c_3789   f   25
# 336818    c_4406   f   24
# 336819    c_2706   f   55
# 336820    c_3443   m   63
# 336821    c_4447   m   66
# 336822    c_3017   f   30
# 336823    c_4086   f   30
# 336824    c_6930   m   18
# 336825    c_4358   m   23
# 336826    c_8381   f   57
# 336827    c_1223   m   59
# 336828    c_6862   f   20
# 336829    c_5245   f   18
# 336830    c_5223   m   19
# 336831    c_6735   m   18
# 336832     c_862   f   66
# 336833    c_7584   f   62
# 336834      c_90   m   21
# 336835     c_587   m   29
# 336836    c_3526   m   66

# %% [markdown]
# Nous avons cree un df qui contient uniquement les produits vendu et les clients qui ont acheté.

# %%
dataset= tables[tables['id_prod'].notnull()]
dataset
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450   4.99    0.0
# 1       0_1085  2021-09-29 11:14:59.793823    s_97382    c_4450   3.99    0.0
# 2       0_1453  2021-08-27 19:50:46.796939    s_81509    c_4450   7.99    0.0
# 3       0_1405  2021-08-27 20:07:25.878440    s_81509    c_4450   4.99    0.0
# 4       0_1392  2021-12-28 11:45:04.072281   s_141302    c_4450   6.30    0.0
# ...        ...                         ...        ...       ...    ...    ...
# 336811   1_607  2021-09-25 07:26:00.224331    s_95185    c_4786  26.99    1.0
# 336812   1_673  2021-06-01 00:49:49.781631    s_42350    c_2793  12.99    1.0
# 336813  0_2075  2021-10-09 09:03:48.268536   s_102200    c_2793   8.99    0.0
# 336814  0_1692  2021-09-15 19:42:08.596375    s_90430    c_4478  13.36    0.0
# 336815   0_142  2021-09-25 18:07:25.880052    s_95415    c_1232  19.85    0.0
#
#        _merge sex  birth  Age
# 0        both   f   1977   45
# 1        both   f   1977   45
# 2        both   f   1977   45
# 3        both   f   1977   45
# 4        both   f   1977   45
# ...       ...  ..    ...  ...
# 336811   both   f   1967   55
# 336812   both   m   1933   89
# 336813   both   m   1933   89
# 336814   both   f   1970   52
# 336815   both   f   1960   62
#
# [336816 rows x 10 columns]

# %% [markdown]
# Nous avons supprimé la colonne merge qui ne nous est plus utile.

# %%
dataset= dataset.drop('_merge', axis=1)
dataset
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450   4.99    0.0
# 1       0_1085  2021-09-29 11:14:59.793823    s_97382    c_4450   3.99    0.0
# 2       0_1453  2021-08-27 19:50:46.796939    s_81509    c_4450   7.99    0.0
# 3       0_1405  2021-08-27 20:07:25.878440    s_81509    c_4450   4.99    0.0
# 4       0_1392  2021-12-28 11:45:04.072281   s_141302    c_4450   6.30    0.0
# ...        ...                         ...        ...       ...    ...    ...
# 336811   1_607  2021-09-25 07:26:00.224331    s_95185    c_4786  26.99    1.0
# 336812   1_673  2021-06-01 00:49:49.781631    s_42350    c_2793  12.99    1.0
# 336813  0_2075  2021-10-09 09:03:48.268536   s_102200    c_2793   8.99    0.0
# 336814  0_1692  2021-09-15 19:42:08.596375    s_90430    c_4478  13.36    0.0
# 336815   0_142  2021-09-25 18:07:25.880052    s_95415    c_1232  19.85    0.0
#
#        sex  birth  Age
# 0        f   1977   45
# 1        f   1977   45
# 2        f   1977   45
# 3        f   1977   45
# 4        f   1977   45
# ...     ..    ...  ...
# 336811   f   1967   55
# 336812   m   1933   89
# 336813   m   1933   89
# 336814   f   1970   52
# 336815   f   1960   62
#
# [336816 rows x 9 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 336816 entries, 0 to 336815
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id_prod     336816 non-null  object
#  1   date        336816 non-null  object
#  2   session_id  336816 non-null  object
#  3   client_id   336816 non-null  object
#  4   price       336713 non-null  float64
#  5   categ       336713 non-null  float64
#  6   sex         336816 non-null  object
#  7   birth       336816 non-null  int64
#  8   Age         336816 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 25.7+ MB

# %% [markdown]
# Grâce à la fonction info(), nous pouvons observé qu'il manque des valeurs pour les colonnes prix et categ ( pour 103 lignes)

# %% [markdown]
# ## D. Analyse des données <a class="anchor" id="chapitre4"></a>

# %% [markdown]
# ### 1. Identification de produits sans prix <a class="anchor" id="petit11"></a>

# %% [markdown]
# Nous avons regroupé les valeurs dans un df pour pouvoir les travaillés.

# %%
prix_nul= dataset[dataset['price'].isnull()]
prix_nul
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 18202   0_2245  2021-06-05 17:04:43.982913    s_44481    c_6714    NaN    NaN
# 18203   0_2245  2021-04-22 04:57:20.090378    s_23987    c_6714    NaN    NaN
# 20708   0_2245  2021-04-17 16:43:16.543156    s_21906    c_7808    NaN    NaN
# 27016   0_2245  2021-11-01 14:00:26.535213   s_113219    c_7810    NaN    NaN
# 30498   0_2245  2021-09-11 10:52:05.205583    s_88251    c_3468    NaN    NaN
# ...        ...                         ...        ...       ...    ...    ...
# 299794  0_2245  2021-09-19 03:08:45.918021    s_92049    c_4935    NaN    NaN
# 311031  0_2245  2021-11-12 09:25:22.905886   s_118458    c_7416    NaN    NaN
# 311482  0_2245  2021-06-17 03:03:12.668129    s_49705    c_1533    NaN    NaN
# 324186  0_2245  2021-11-20 20:21:06.505658   s_122593    c_8524    NaN    NaN
# 325475  0_2245  2021-05-20 07:44:21.415061    s_36985    c_1450    NaN    NaN
#
#        sex  birth  Age
# 18202    f   1968   54
# 18203    f   1968   54
# 20708    m   1977   45
# 27016    m   1978   44
# 30498    f   1981   41
# ...     ..    ...  ...
# 299794   f   1982   40
# 311031   m   1933   89
# 311482   m   1972   50
# 324186   f   1982   40
# 325475   f   1959   63
#
# [103 rows x 9 columns]

# %%
prix_nul.count()
# Out:
# id_prod       103
# date          103
# session_id    103
# client_id     103
# price           0
# categ           0
# sex           103
# birth         103
# Age           103
# dtype: int64

# %% [markdown]
# Les données manquante ne semble correspondre que pour le produit 0_2245. Dans un premier temps nous avons associé le produit a la categorie 0.0 ( comme l'indique le 0_ devant le numéro.

# %%
dataset['categ'].loc[ dataset['id_prod'] == '0_2245'] = 0.0

# %%
dataset
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450   4.99    0.0
# 1       0_1085  2021-09-29 11:14:59.793823    s_97382    c_4450   3.99    0.0
# 2       0_1453  2021-08-27 19:50:46.796939    s_81509    c_4450   7.99    0.0
# 3       0_1405  2021-08-27 20:07:25.878440    s_81509    c_4450   4.99    0.0
# 4       0_1392  2021-12-28 11:45:04.072281   s_141302    c_4450   6.30    0.0
# ...        ...                         ...        ...       ...    ...    ...
# 336811   1_607  2021-09-25 07:26:00.224331    s_95185    c_4786  26.99    1.0
# 336812   1_673  2021-06-01 00:49:49.781631    s_42350    c_2793  12.99    1.0
# 336813  0_2075  2021-10-09 09:03:48.268536   s_102200    c_2793   8.99    0.0
# 336814  0_1692  2021-09-15 19:42:08.596375    s_90430    c_4478  13.36    0.0
# 336815   0_142  2021-09-25 18:07:25.880052    s_95415    c_1232  19.85    0.0
#
#        sex  birth  Age
# 0        f   1977   45
# 1        f   1977   45
# 2        f   1977   45
# 3        f   1977   45
# 4        f   1977   45
# ...     ..    ...  ...
# 336811   f   1967   55
# 336812   m   1933   89
# 336813   m   1933   89
# 336814   f   1970   52
# 336815   f   1960   62
#
# [336816 rows x 9 columns]

# %% [markdown]
# Nous avons ensuite calculer le prix moyen de la categorie 0.0. Nous donnerons ce prix au produit 0_2245.

# %%
prix= dataset[dataset['price'].notnull()]
prix_categ= prix['price'].groupby(prix['categ']).describe()

# %%
prix_categ
# Out:
#           count       mean        std    min    25%    50%    75%     max
# categ
# 0.0    209426.0  10.646828   4.930030   0.62   6.30   9.99  14.45   40.99
# 1.0    109735.0  20.480106   7.568956   2.00  15.81  19.08  24.98   80.99
# 2.0     17552.0  75.174949  39.079999  30.99  53.99  62.83  71.21  300.00

# %%
dataset['price'].fillna(9.99, inplace = True)

# %%
verif= dataset.loc[dataset['id_prod'] == '0_2245']

# %%
verif
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 18202   0_2245  2021-06-05 17:04:43.982913    s_44481    c_6714   9.99    0.0
# 18203   0_2245  2021-04-22 04:57:20.090378    s_23987    c_6714   9.99    0.0
# 20708   0_2245  2021-04-17 16:43:16.543156    s_21906    c_7808   9.99    0.0
# 27016   0_2245  2021-11-01 14:00:26.535213   s_113219    c_7810   9.99    0.0
# 30498   0_2245  2021-09-11 10:52:05.205583    s_88251    c_3468   9.99    0.0
# ...        ...                         ...        ...       ...    ...    ...
# 299794  0_2245  2021-09-19 03:08:45.918021    s_92049    c_4935   9.99    0.0
# 311031  0_2245  2021-11-12 09:25:22.905886   s_118458    c_7416   9.99    0.0
# 311482  0_2245  2021-06-17 03:03:12.668129    s_49705    c_1533   9.99    0.0
# 324186  0_2245  2021-11-20 20:21:06.505658   s_122593    c_8524   9.99    0.0
# 325475  0_2245  2021-05-20 07:44:21.415061    s_36985    c_1450   9.99    0.0
#
#        sex  birth  Age
# 18202    f   1968   54
# 18203    f   1968   54
# 20708    m   1977   45
# 27016    m   1978   44
# 30498    f   1981   41
# ...     ..    ...  ...
# 299794   f   1982   40
# 311031   m   1933   89
# 311482   m   1972   50
# 324186   f   1982   40
# 325475   f   1959   63
#
# [103 rows x 9 columns]

# %% [markdown]
# ### 2. Identification de clients pro <a class="anchor" id="petit12"></a>

# %% [markdown]
# Nous avons décidé par la suite d'etudié les clients. Dans un premier temps nous avons regroupé les lignes client afin de calculerle nombre et la frequence d'achat.

# %%
cliens = dataset['client_id'].groupby(dataset['client_id'])
Cliensdescribe= cliens.describe()

# %%
testclientcount = Cliensdescribe.sort_values(by= ['count'], ascending= False)
testclientcount
# Out:
#            count unique     top   freq
# client_id
# c_1609     12855      1  c_1609  12855
# c_6714      4473      1  c_6714   4473
# c_3454      3275      1  c_3454   3275
# c_4958      2562      1  c_4958   2562
# c_2140       195      1  c_2140    195
# ...          ...    ...     ...    ...
# c_5401         1      1  c_5401      1
# c_7089         1      1  c_7089      1
# c_7534         1      1  c_7534      1
# c_240          1      1   c_240      1
# c_6610         1      1  c_6610      1
#
# [8600 rows x 4 columns]

# %% [markdown]
# Nous pouvons observé que pour 4 clients, il y a une quantité d'achat plus important. Ce sont des clients pro que nous avons par la suite éliminé du dataset.

# %%
client_pro1= dataset.loc[(dataset['client_id'] == 'c_1609')]
client_pro1
# Out:
#       id_prod                        date session_id client_id  price  categ  \
# 468    0_1483  2021-09-19 08:45:43.735331    s_92165    c_1609   4.99    0.0
# 469    0_1483  2021-07-22 20:45:15.286364    s_65805    c_1609   4.99    0.0
# 470    0_1483  2021-05-08 06:20:05.395325    s_31519    c_1609   4.99    0.0
# 471    0_1483  2021-04-17 06:01:35.017859    s_21725    c_1609   4.99    0.0
# 472    0_1483  2021-06-06 13:42:00.282408    s_44891    c_1609   4.99    0.0
# ...       ...                         ...        ...       ...    ...    ...
# 13318  0_1510  2021-12-13 03:03:26.954212   s_133559    c_1609   2.18    0.0
# 13319  0_2094  2021-04-17 10:40:16.165711    s_21800    c_1609  29.02    0.0
# 13320  0_1871  2021-11-01 07:26:17.783922   s_113092    c_1609   1.99    0.0
# 13321   1_470  2021-03-04 09:41:40.700704     s_1550    c_1609   5.41    1.0
# 13322  0_1191  2021-06-20 12:48:50.925796    s_51304    c_1609   0.99    0.0
#
#       sex  birth  Age
# 468     m   1980   42
# 469     m   1980   42
# 470     m   1980   42
# 471     m   1980   42
# 472     m   1980   42
# ...    ..    ...  ...
# 13318   m   1980   42
# 13319   m   1980   42
# 13320   m   1980   42
# 13321   m   1980   42
# 13322   m   1980   42
#
# [12855 rows x 9 columns]

# %%
client_pro2= dataset.loc[(dataset['client_id'] == 'c_6714')]
client_pro2
# Out:
#       id_prod                        date session_id client_id  price  categ  \
# 14096  0_1483  2021-03-31 23:22:23.322344    s_14189    c_6714   4.99    0.0
# 14097  0_1483  2022-02-12 00:32:17.901505   s_163732    c_6714   4.99    0.0
# 14098  0_1483  2021-08-31 18:14:30.540161    s_83213    c_6714   4.99    0.0
# 14099  0_1483  2021-07-12 08:48:43.942437    s_61210    c_6714   4.99    0.0
# 14100  0_1483  2021-10-18 00:37:40.839327   s_106349    c_6714   4.99    0.0
# ...       ...                         ...        ...       ...    ...    ...
# 18564   0_463  2021-10-25 16:08:55.254314   s_109996    c_6714  21.99    0.0
# 18565     0_4  2021-06-12 14:15:12.255210    s_47663    c_6714  25.33    0.0
# 18566  0_1427  2021-09-28 14:49:32.669709    s_96895    c_6714  28.99    0.0
# 18567  0_1504  2022-01-14 00:13:55.781594   s_149434    c_6714   1.68    0.0
# 18568  0_1533  2021-10-10 05:12:32.735349   s_102608    c_6714  27.99    0.0
#
#       sex  birth  Age
# 14096   f   1968   54
# 14097   f   1968   54
# 14098   f   1968   54
# 14099   f   1968   54
# 14100   f   1968   54
# ...    ..    ...  ...
# 18564   f   1968   54
# 18565   f   1968   54
# 18566   f   1968   54
# 18567   f   1968   54
# 18568   f   1968   54
#
# [4473 rows x 9 columns]

# %%
client_pro3= dataset.loc[(dataset['client_id'] == 'c_3454')]
client_pro3
# Out:
#       id_prod                        date session_id client_id  price  categ  \
# 33164  0_1483  2021-05-05 04:10:01.817161    s_30091    c_3454   4.99    0.0
# 33165  0_1483  2021-07-02 19:55:15.446880    s_56999    c_3454   4.99    0.0
# 33166   1_374  2021-12-03 18:21:29.785885   s_128912    c_3454  10.71    1.0
# 33167   1_374  2021-11-03 12:09:00.400716   s_114148    c_3454  10.71    1.0
# 33168   1_374  2021-12-07 20:36:11.333745   s_130934    c_3454  10.71    1.0
# ...       ...                         ...        ...       ...    ...    ...
# 36434   0_248  2021-12-07 08:36:09.755656   s_130699    c_3454   7.91    0.0
# 36435  0_1664  2021-04-16 23:14:34.098086    s_21595    c_3454  25.72    0.0
# 36436  0_2275  2021-04-28 07:50:05.162940    s_26890    c_3454   0.99    0.0
# 36437   0_787  2021-07-13 04:59:54.674051    s_61583    c_3454   7.99    0.0
# 36438  0_1726  2021-06-12 14:46:57.166761    s_47673    c_3454   1.57    0.0
#
#       sex  birth  Age
# 33164   m   1969   53
# 33165   m   1969   53
# 33166   m   1969   53
# 33167   m   1969   53
# 33168   m   1969   53
# ...    ..    ...  ...
# 36434   m   1969   53
# 36435   m   1969   53
# 36436   m   1969   53
# 36437   m   1969   53
# 36438   m   1969   53
#
# [3275 rows x 9 columns]

# %%
client_pro4= dataset.loc[(dataset['client_id'] == 'c_4958')]
client_pro4
# Out:
#       id_prod                        date session_id client_id   price  categ  \
# 47320   2_226  2021-10-21 04:36:39.040658   s_107870    c_4958   65.75    2.0
# 47321   2_226  2022-02-23 13:18:03.834049   s_169643    c_4958   65.75    2.0
# 47322   2_226  2022-02-10 02:01:49.656771   s_162717    c_4958   65.75    2.0
# 47323   2_226  2021-06-12 06:53:15.771070    s_47520    c_4958   65.75    2.0
# 47324   2_226  2021-05-19 22:48:03.386157    s_36817    c_4958   65.75    2.0
# ...       ...                         ...        ...       ...     ...    ...
# 49877    2_56  2022-02-19 01:11:43.968933   s_167365    c_4958  116.67    2.0
# 49878   2_118  2021-11-25 16:43:53.859352   s_124927    c_4958   96.56    2.0
# 49879   2_130  2021-09-22 23:46:27.276691    s_93974    c_4958  142.58    2.0
# 49880    2_27  2021-08-22 18:17:11.182730    s_79265    c_4958   73.99    2.0
# 49881     2_4  2021-03-24 03:00:33.392992    s_10641    c_4958  222.97    2.0
#
#       sex  birth  Age
# 47320   m   1999   23
# 47321   m   1999   23
# 47322   m   1999   23
# 47323   m   1999   23
# 47324   m   1999   23
# ...    ..    ...  ...
# 49877   m   1999   23
# 49878   m   1999   23
# 49879   m   1999   23
# 49880   m   1999   23
# 49881   m   1999   23
#
# [2562 rows x 9 columns]

# %%
type_achat_client1= client_pro1 ['price'].groupby(client_pro1['categ']).describe()
todataframe(type_achat_client1['count'])
# Out:
#    categ    count
# 0    0.0  10286.0
# 1    1.0   2568.0
# 2    2.0      1.0

# %%
type_achat_client2= client_pro2['price'].groupby(client_pro2['categ']).describe()
todataframe(type_achat_client2['count'])
# Out:
#    categ   count
# 0    0.0  2640.0
# 1    1.0  1695.0
# 2    2.0   138.0

# %%
type_achat_client3= client_pro3['price'].groupby(client_pro3['categ']).describe()
todataframe(type_achat_client3['count'])
# Out:
#    categ   count
# 0    0.0  1330.0
# 1    1.0  1937.0
# 2    2.0     8.0

# %%
type_achat_client4= client_pro4['price'].groupby(client_pro4['categ']).describe()
todataframe(type_achat_client4['count'])
# Out:
#    categ   count
# 0    0.0     3.0
# 1    1.0   910.0
# 2    2.0  1649.0

# %% [markdown]
# En groupant les produits acheté par les clients pro par rapport a leur categorie, nous pouvons voir ici leurs préferences d'achats.

# %% [markdown]
# Pour la suite des analyses nous avons donc supprimé les client pro du df.

# %%
dataset2 = dataset.copy()
dataset2.drop(dataset.loc[dataset['client_id']== 'c_4958'].index, inplace=True)
dataset2.drop(dataset.loc[dataset['client_id']== 'c_1609'].index, inplace=True)
dataset2.drop(dataset.loc[dataset['client_id']== 'c_6714'].index, inplace=True)
dataset2.drop(dataset.loc[dataset['client_id']== 'c_3454'].index, inplace=True)
dataset2
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450   4.99    0.0
# 1       0_1085  2021-09-29 11:14:59.793823    s_97382    c_4450   3.99    0.0
# 2       0_1453  2021-08-27 19:50:46.796939    s_81509    c_4450   7.99    0.0
# 3       0_1405  2021-08-27 20:07:25.878440    s_81509    c_4450   4.99    0.0
# 4       0_1392  2021-12-28 11:45:04.072281   s_141302    c_4450   6.30    0.0
# ...        ...                         ...        ...       ...    ...    ...
# 336811   1_607  2021-09-25 07:26:00.224331    s_95185    c_4786  26.99    1.0
# 336812   1_673  2021-06-01 00:49:49.781631    s_42350    c_2793  12.99    1.0
# 336813  0_2075  2021-10-09 09:03:48.268536   s_102200    c_2793   8.99    0.0
# 336814  0_1692  2021-09-15 19:42:08.596375    s_90430    c_4478  13.36    0.0
# 336815   0_142  2021-09-25 18:07:25.880052    s_95415    c_1232  19.85    0.0
#
#        sex  birth  Age
# 0        f   1977   45
# 1        f   1977   45
# 2        f   1977   45
# 3        f   1977   45
# 4        f   1977   45
# ...     ..    ...  ...
# 336811   f   1967   55
# 336812   m   1933   89
# 336813   m   1933   89
# 336814   f   1970   52
# 336815   f   1960   62
#
# [313651 rows x 9 columns]

# %%
cliens2 = dataset2['client_id'].groupby(dataset2['client_id'])
t = cliens2.describe()
testclientcount2 = t.sort_values(by= ['count'], ascending= False)
testclientcount2
# Out:
#           count unique     top freq
# client_id
# c_2140      195      1  c_2140  195
# c_7959      195      1  c_7959  195
# c_8026      193      1  c_8026  193
# c_2595      193      1  c_2595  193
# c_3725      190      1  c_3725  190
# ...         ...    ...     ...  ...
# c_6200        1      1  c_6200    1
# c_4648        1      1  c_4648    1
# c_8351        1      1  c_8351    1
# c_6837        1      1  c_6837    1
# c_1232        1      1  c_1232    1
#
# [8596 rows x 4 columns]

# %% [markdown]
# Nous avons verifié ici que nous avions bien supprimé les clients pro.

# %% [markdown]
# ### 3. Etude temporel  <a class="anchor" id="petit13"></a>

# %% [markdown]
# Nous avons commencer par crée des colonnes année, mois et jours pour y vois un peu plus clair dans les données.

# %%
dataset2['Année'] = pd.DatetimeIndex(dataset2['date']).year
dataset2
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450   4.99    0.0
# 1       0_1085  2021-09-29 11:14:59.793823    s_97382    c_4450   3.99    0.0
# 2       0_1453  2021-08-27 19:50:46.796939    s_81509    c_4450   7.99    0.0
# 3       0_1405  2021-08-27 20:07:25.878440    s_81509    c_4450   4.99    0.0
# 4       0_1392  2021-12-28 11:45:04.072281   s_141302    c_4450   6.30    0.0
# ...        ...                         ...        ...       ...    ...    ...
# 336811   1_607  2021-09-25 07:26:00.224331    s_95185    c_4786  26.99    1.0
# 336812   1_673  2021-06-01 00:49:49.781631    s_42350    c_2793  12.99    1.0
# 336813  0_2075  2021-10-09 09:03:48.268536   s_102200    c_2793   8.99    0.0
# 336814  0_1692  2021-09-15 19:42:08.596375    s_90430    c_4478  13.36    0.0
# 336815   0_142  2021-09-25 18:07:25.880052    s_95415    c_1232  19.85    0.0
#
#        sex  birth  Age  Année
# 0        f   1977   45   2021
# 1        f   1977   45   2021
# 2        f   1977   45   2021
# 3        f   1977   45   2021
# 4        f   1977   45   2021
# ...     ..    ...  ...    ...
# 336811   f   1967   55   2021
# 336812   m   1933   89   2021
# 336813   m   1933   89   2021
# 336814   f   1970   52   2021
# 336815   f   1960   62   2021
#
# [313651 rows x 10 columns]

# %%
dataset2['mois'] = pd.DatetimeIndex(dataset2['date']).month
dataset2
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450   4.99    0.0
# 1       0_1085  2021-09-29 11:14:59.793823    s_97382    c_4450   3.99    0.0
# 2       0_1453  2021-08-27 19:50:46.796939    s_81509    c_4450   7.99    0.0
# 3       0_1405  2021-08-27 20:07:25.878440    s_81509    c_4450   4.99    0.0
# 4       0_1392  2021-12-28 11:45:04.072281   s_141302    c_4450   6.30    0.0
# ...        ...                         ...        ...       ...    ...    ...
# 336811   1_607  2021-09-25 07:26:00.224331    s_95185    c_4786  26.99    1.0
# 336812   1_673  2021-06-01 00:49:49.781631    s_42350    c_2793  12.99    1.0
# 336813  0_2075  2021-10-09 09:03:48.268536   s_102200    c_2793   8.99    0.0
# 336814  0_1692  2021-09-15 19:42:08.596375    s_90430    c_4478  13.36    0.0
# 336815   0_142  2021-09-25 18:07:25.880052    s_95415    c_1232  19.85    0.0
#
#        sex  birth  Age  Année  mois
# 0        f   1977   45   2021     4
# 1        f   1977   45   2021     9
# 2        f   1977   45   2021     8
# 3        f   1977   45   2021     8
# 4        f   1977   45   2021    12
# ...     ..    ...  ...    ...   ...
# 336811   f   1967   55   2021     9
# 336812   m   1933   89   2021     6
# 336813   m   1933   89   2021    10
# 336814   f   1970   52   2021     9
# 336815   f   1960   62   2021     9
#
# [313651 rows x 11 columns]

# %%
dataset2['jour'] = pd.DatetimeIndex(dataset2['date']).day
dataset2
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450   4.99    0.0
# 1       0_1085  2021-09-29 11:14:59.793823    s_97382    c_4450   3.99    0.0
# 2       0_1453  2021-08-27 19:50:46.796939    s_81509    c_4450   7.99    0.0
# 3       0_1405  2021-08-27 20:07:25.878440    s_81509    c_4450   4.99    0.0
# 4       0_1392  2021-12-28 11:45:04.072281   s_141302    c_4450   6.30    0.0
# ...        ...                         ...        ...       ...    ...    ...
# 336811   1_607  2021-09-25 07:26:00.224331    s_95185    c_4786  26.99    1.0
# 336812   1_673  2021-06-01 00:49:49.781631    s_42350    c_2793  12.99    1.0
# 336813  0_2075  2021-10-09 09:03:48.268536   s_102200    c_2793   8.99    0.0
# 336814  0_1692  2021-09-15 19:42:08.596375    s_90430    c_4478  13.36    0.0
# 336815   0_142  2021-09-25 18:07:25.880052    s_95415    c_1232  19.85    0.0
#
#        sex  birth  Age  Année  mois  jour
# 0        f   1977   45   2021     4    10
# 1        f   1977   45   2021     9    29
# 2        f   1977   45   2021     8    27
# 3        f   1977   45   2021     8    27
# 4        f   1977   45   2021    12    28
# ...     ..    ...  ...    ...   ...   ...
# 336811   f   1967   55   2021     9    25
# 336812   m   1933   89   2021     6     1
# 336813   m   1933   89   2021    10     9
# 336814   f   1970   52   2021     9    15
# 336815   f   1960   62   2021     9    25
#
# [313651 rows x 12 columns]

# %% [markdown]
# On a cherché a voir s'il y avait des changements dans les ventes des trois categories en fonction des dates de sessions.

# %%
hue_order = [2.0, 1.0, 0.0]
color = ['green','deepskyblue','red']
sns.histplot(data = dataset2,  x = 'date',hue= 'categ', palette=color, hue_order=hue_order)
# Out:
# <AxesSubplot:xlabel='date', ylabel='Count'>

# %% [markdown]
# On peut observer qu'il  y a un manque d'information ou de vente sur la categorie 1.0 au moins d'octobre.

# %%
Activite_baisse= dataset2.loc[(dataset2['Année'] == 2021) & (dataset2['mois'] >= 10) &  (dataset2['mois'] < 11) & (dataset2['jour'] <= 31)]
color = ['green','deepskyblue','red']
sns.histplot(data = Activite_baisse,  x = 'date',  hue= 'categ', palette=color, hue_order=hue_order)
plt.xticks(rotation=45)
# Out:
# (array([18901., 18905., 18909., 18913., 18917., 18921., 18925., 18929.,
#         18932.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ### 4. Observation du prix des produits par categorie  <a class="anchor" id="petit14"></a>

# %% [markdown]
# Réalisation d'un boxplot pour observé la repartition des prix celon les catégories.

# %%
sns.boxplot(data=dataset2, x="categ", y="price", palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='categ', ylabel='price'>

# %% [markdown]
# On observe que la catégorie 2 contient les produits les plus cher.

# %% [markdown]
# ### 5. Calcule du chiffre d'affaire <a class="anchor" id="petit15"></a>

# %% [markdown]
# #### a) Chiffre d'affaire avec les pro <a class="anchor" id="tit11"></a>

# %% [markdown]
# Calcule du chiffre d'affaire avec les clients pro.

# %%
data_montant_pro = dataset[['client_id','price']]
client_montant_pro = data_montant_pro.groupby(['client_id'])["price"].sum()
df_client_montant_pro= todataframe(client_montant_pro)
df_client_montant_pro.rename(columns = {'price':'ca'}, inplace = True)
df_client_montant_pro = df_client_montant_pro.sort_values(by ="ca", ascending=False )
df_client_montant_pro
# Out:
#      client_id         ca
# 677     c_1609  162007.34
# 4388    c_4958  144257.21
# 6337    c_6714   73217.32
# 2724    c_3454   54462.90
# 7715    c_7959    2564.25
# ...        ...        ...
# 8151    c_8351       6.31
# 8480     c_890       6.08
# 750     c_1675       5.57
# 7889    c_8114       4.99
# 7918    c_8140       4.15
#
# [8600 rows x 2 columns]

# %%
caTotalAvecLesPro =client_montant_pro.sum()
caTotalAvecLesPro
# Out:
# 5797606.739999999

# %% [markdown]
# Le chiffre d'affaire est de 5797606.7 euros ( si la libraire est en UE).

# %% [markdown]
# #### b) chiffre d'affaire sans les pro <a class="anchor" id="tit12"></a>

# %%
data_montant = dataset2[['client_id','price']]
client_montant = data_montant.groupby(['client_id'])["price"].sum()
client_montant 
client_montant = todataframe(client_montant)
client_montant.rename(columns = {'price':'ca'}, inplace = True)
client_montant= client_montant.sort_values(by ="ca", ascending=False )
client_montant
# Out:
#      client_id       ca
# 7711    c_7959  2564.25
# 7787    c_8026  2547.66
# 3868    c_4491  2540.53
# 1267    c_2140  2527.01
# 8191    c_8392  2515.98
# ...        ...      ...
# 8147    c_8351     6.31
# 8476     c_890     6.08
# 749     c_1675     5.57
# 7885    c_8114     4.99
# 7914    c_8140     4.15
#
# [8596 rows x 2 columns]

# %%
caTotalSansLesPro = client_montant.sum()
caTotalSansLesPro
# Out:
# client_id    c_7959c_8026c_4491c_2140c_8392c_7421c_3263c_37...
# ca                                                  5363661.97
# dtype: object

# %% [markdown]
# Le chiffre d'affaire est de 5363661.97 euros sans les clients pro qui rapportent 433944.77 au ca total.

# %% [markdown]
# Les clients ayant le plus dépensé:

# %%
sns.set(rc={"figure.figsize":(8,5)},style='whitegrid')
sns.barplot(data=client_montant.sort_values('ca', ascending=False).head(15),y='client_id',x='ca',palette='Set2')
# Out:
# <AxesSubplot:xlabel='ca', ylabel='client_id'>

# %% [markdown]
# Les clients qui ont le moins dépensé:

# %%
sns.barplot(data=client_montant.sort_values('ca', ascending=False).tail(20),y='client_id',x='ca',palette='Set2')
# Out:
# <AxesSubplot:xlabel='ca', ylabel='client_id'>

# %% [markdown]
# #### c) chiffre d'affaire par produit <a class="anchor" id="tit13"></a>

# %%
chiffre_affaire = dataset2.groupby(['id_prod','categ'])["price"].sum()
chiffre_affaire = todataframe(chiffre_affaire)
chiffre_affaire.rename(columns = {'price':'ca'}, inplace = True)
chiffre_affaire=chiffre_affaire.sort_values(by ="ca", ascending=False )
chiffre_affaire
# Out:
#      id_prod  categ        ca
# 3067   2_135    2.0  30976.51
# 3043   2_112    2.0  28649.68
# 3032   2_102    2.0  26199.02
# 2589   1_369    1.0  24349.85
# 3149   2_209    2.0  24286.53
# ...      ...    ...       ...
# 312   0_1284    0.0      1.38
# 924   0_1840    0.0      1.28
# 594   0_1539    0.0      0.99
# 718   0_1653    0.0      0.99
# 209   0_1191    0.0      0.99
#
# [3262 rows x 3 columns]

# %% [markdown]
# Nous avons calculé le Chiffre d'affaire par produit. Puis nous avons regardé quel categorie de produit rapportait le plus.

# %%
produit_cat_montant = dataset2.groupby(['categ'])["price"].sum()
df1 =  todataframe(produit_cat_montant) 
df1.rename(columns = {'price':'ca'}, inplace = True)
df1
# Out:
#    categ          ca
# 0    0.0  2078594.02
# 1    1.0  2101585.34
# 2    2.0  1183482.61

# %%
mp.pyplot.pie(x=df1.ca,labels=['Categorie 0','Categorie 1','Categorie 2'],  autopct='%1.1f%%',explode=[0.1,0.1,0.2], colors= ['r', 'b','g'])
# Out:
# ([<matplotlib.patches.Wedge at 0x25a0a150b20>,
#   <matplotlib.patches.Wedge at 0x25a0a160280>,
#   <matplotlib.patches.Wedge at 0x25a0a1609a0>],
#  [Text(0.4152250869617982, 1.1258721628842092, 'Categorie 0'),
#   Text(-1.038819894179687, -0.6007106020843185, 'Categorie 1'),
#   Text(0.9999774982340919, -0.8306894744882031, 'Categorie 2')],
#  [Text(0.24221463406104893, 0.6567587616824554, '38.8%'),
#   Text(-0.6059782716048173, -0.35041451788251904, '39.2%'),
#   Text(0.6153707681440566, -0.511193522761971, '22.1%')])

# %% [markdown]
# ### 6. Recherche et identification d'outliers <a class="anchor" id="petit16"></a>

# %% [markdown]
#  calcule du quartile pour calculer les out

# %%
q1=np.quantile(chiffre_affaire['ca'],0.25)
q3=np.quantile(chiffre_affaire['ca'],0.75)
out= (q3 +1.5*(q3-q1)) 
outlier=chiffre_affaire.loc[chiffre_affaire['ca']> out ]
outlier = outlier.sort_values(by='ca', ascending = False)
outlier
# Out:
#      id_prod  categ        ca
# 3067   2_135    2.0  30976.51
# 3043   2_112    2.0  28649.68
# 3032   2_102    2.0  26199.02
# 2589   1_369    1.0  24349.85
# 3149   2_209    2.0  24286.53
# ...      ...    ...       ...
# 681   0_1617    0.0   3800.83
# 68    0_1061    0.0   3798.10
# 3162   2_220    2.0   3793.20
# 2980   1_721    1.0   3782.28
# 2983   1_724    1.0   3777.62
#
# [400 rows x 3 columns]

# %%
sns.set(rc={"figure.figsize":(8,5)},style='whitegrid')
color = ['blue','green']
sns.barplot(data=outlier.head(20),y='id_prod',x='ca',palette=color,  hue="categ")
# Out:
# <AxesSubplot:xlabel='ca', ylabel='id_prod'>

# %% [markdown]
# Regarder les produits qui rapportent le plus nous a donné envie de regarder les produits qui rapportent le moins.

# %%
chiffre_affaire
sns.set(rc={"figure.figsize":(8,5)},style='whitegrid')
sns.barplot(data=chiffre_affaire.sort_values('ca', ascending=False).tail(20),y='id_prod',x='ca',palette='Set1',  hue="categ")
# Out:
# <AxesSubplot:xlabel='ca', ylabel='id_prod'>

# %% [markdown]
# ### 7. Groupe <a class="anchor" id="petit17"></a>

# %% [markdown]
# ##### Chiffre d'affaire par Client :

# %%
client_montant = data_montant.groupby(['client_id'])["price"].sum()
client_montant = todataframe(client_montant)
client_montant.rename(columns = {'price':'ca_client'}, inplace = True)
client_montant = client_montant.sort_values(by ="ca_client", ascending=False )
client_montant
# Out:
#      client_id  ca_client
# 7711    c_7959    2564.25
# 7787    c_8026    2547.66
# 3868    c_4491    2540.53
# 1267    c_2140    2527.01
# 8191    c_8392    2515.98
# ...        ...        ...
# 8147    c_8351       6.31
# 8476     c_890       6.08
# 749     c_1675       5.57
# 7885    c_8114       4.99
# 7914    c_8140       4.15
#
# [8596 rows x 2 columns]

# %% [markdown]
# ##### fréquence de commande des clients

# %%
client_nb_commande = dataset2.groupby(['client_id','Age','sex'])['price'].count()
client_nb_commande = todataframe(client_nb_commande)
client_nb_commande.rename(columns = {'price':'frequence'}, inplace = True)
client_nb_commande
# Out:
#      client_id  Age sex  frequence
# 0          c_1   67   m         20
# 1         c_10   66   m         28
# 2        c_100   30   m          6
# 3       c_1000   56   f         56
# 4       c_1001   40   m         58
# ...        ...  ...  ..        ...
# 8591     c_995   67   m          8
# 8592     c_996   52   f         42
# 8593     c_997   28   f         23
# 8594     c_998   21   m         28
# 8595     c_999   58   m         22
#
# [8596 rows x 4 columns]

# %%
client_d= pd.merge(client_nb_commande, client_montant, on='client_id', how='outer',indicator=True)
client_d= client_d.drop('_merge', axis=1)
client_d
# Out:
#      client_id  Age sex  frequence  ca_client
# 0          c_1   67   m         20     300.65
# 1         c_10   66   m         28     586.18
# 2        c_100   30   m          6     222.87
# 3       c_1000   56   f         56     980.02
# 4       c_1001   40   m         58    1102.45
# ...        ...  ...  ..        ...        ...
# 8591     c_995   67   m          8     119.08
# 8592     c_996   52   f         42     739.60
# 8593     c_997   28   f         23     572.89
# 8594     c_998   21   m         28    1527.69
# 8595     c_999   58   m         22     305.00
#
# [8596 rows x 5 columns]

# %% [markdown]
# ##### Ajout d'une date de  récence

# %%
dataset2['date'] = pd.to_datetime(dataset2['date'])
dateRef = max(dataset2['date'])

# %%
#On crée la fonction pour le Calcul de la recenser :
def CalculRecense(date) :
    recense = dateRef - date
    return(recense.dt.days)

# %%
#On fait une new dataframe ou on prend ceux dont a besoin :
data_date = data1=dataset2[['client_id','date']]
data_client_last_date = data_date.groupby(['client_id']).max()

# %%
datarecence =  CalculRecense(data_client_last_date['date'])
datarecence
# Out:
# client_id
# c_1        27
# c_10       76
# c_100     202
# c_1000      0
# c_1001      2
#          ...
# c_995     116
# c_996      22
# c_997      54
# c_998       5
# c_999       6
# Name: date, Length: 8596, dtype: int64

# %%
#On creer la nouvelle colonne recense  avec les valeur 
data_client_last_date["récence"] =  CalculRecense(data_client_last_date['date'])
data_client_last_date.sort_values(by=['récence'])
data_client_last_date.reset_index()
# Out:
#      client_id                       date  récence
# 0          c_1 2022-02-01 01:47:04.355850       27
# 1         c_10 2021-12-14 09:16:40.399630       76
# 2        c_100 2021-08-10 15:58:52.647110      202
# 3       c_1000 2022-02-28 08:19:38.189089        0
# 4       c_1001 2022-02-26 15:08:28.714777        2
# ...        ...                        ...      ...
# 8591     c_995 2021-11-04 12:35:05.210300      116
# 8592     c_996 2022-02-06 16:40:04.292360       22
# 8593     c_997 2022-01-05 02:02:14.787358       54
# 8594     c_998 2022-02-23 17:54:34.183475        5
# 8595     c_999 2022-02-22 22:55:44.758949        6
#
# [8596 rows x 3 columns]

# %% [markdown]
# ##### Creation du tableau RFM ( résence, frequence, montant)

# %%
rfm= pd.merge(client_d, data_client_last_date, on='client_id', how='outer',indicator=True)
rfm= rfm.drop('_merge', axis=1)
rfm
# Out:
#      client_id  Age sex  frequence  ca_client                       date  \
# 0          c_1   67   m         20     300.65 2022-02-01 01:47:04.355850
# 1         c_10   66   m         28     586.18 2021-12-14 09:16:40.399630
# 2        c_100   30   m          6     222.87 2021-08-10 15:58:52.647110
# 3       c_1000   56   f         56     980.02 2022-02-28 08:19:38.189089
# 4       c_1001   40   m         58    1102.45 2022-02-26 15:08:28.714777
# ...        ...  ...  ..        ...        ...                        ...
# 8591     c_995   67   m          8     119.08 2021-11-04 12:35:05.210300
# 8592     c_996   52   f         42     739.60 2022-02-06 16:40:04.292360
# 8593     c_997   28   f         23     572.89 2022-01-05 02:02:14.787358
# 8594     c_998   21   m         28    1527.69 2022-02-23 17:54:34.183475
# 8595     c_999   58   m         22     305.00 2022-02-22 22:55:44.758949
#
#       récence
# 0          27
# 1          76
# 2         202
# 3           0
# 4           2
# ...       ...
# 8591      116
# 8592       22
# 8593       54
# 8594        5
# 8595        6
#
# [8596 rows x 7 columns]

# %%
rfm["Age"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8596 entries, 0 to 8595
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 8596 non-null   int64
# dtypes: int64(1)
# memory usage: 134.3 KB

# %%
rfm['AgeGroup']= pd.cut(x=rfm["Age"],bins= [18,30,45,60,75,95], labels=['(18, 30]','(30, 45]','(45, 60]','(60, 75]','(75, 95]'] )
rfm
# Out:
#      client_id  Age sex  frequence  ca_client                       date  \
# 0          c_1   67   m         20     300.65 2022-02-01 01:47:04.355850
# 1         c_10   66   m         28     586.18 2021-12-14 09:16:40.399630
# 2        c_100   30   m          6     222.87 2021-08-10 15:58:52.647110
# 3       c_1000   56   f         56     980.02 2022-02-28 08:19:38.189089
# 4       c_1001   40   m         58    1102.45 2022-02-26 15:08:28.714777
# ...        ...  ...  ..        ...        ...                        ...
# 8591     c_995   67   m          8     119.08 2021-11-04 12:35:05.210300
# 8592     c_996   52   f         42     739.60 2022-02-06 16:40:04.292360
# 8593     c_997   28   f         23     572.89 2022-01-05 02:02:14.787358
# 8594     c_998   21   m         28    1527.69 2022-02-23 17:54:34.183475
# 8595     c_999   58   m         22     305.00 2022-02-22 22:55:44.758949
#
#       récence  AgeGroup
# 0          27  (60, 75]
# 1          76  (60, 75]
# 2         202  (18, 30]
# 3           0  (45, 60]
# 4           2  (30, 45]
# ...       ...       ...
# 8591      116  (60, 75]
# 8592       22  (45, 60]
# 8593       54  (18, 30]
# 8594        5  (18, 30]
# 8595        6  (45, 60]
#
# [8596 rows x 8 columns]

# %%
sns.countplot(data=rfm, y= "AgeGroup", palette = 'pastel')
# Out:
# <AxesSubplot:xlabel='count', ylabel='AgeGroup'>

# %%
sns.relplot(data=rfm, x="AgeGroup", y="frequence", kind="line")

# %% [markdown]
# ##### Observation des fréquences d'achat et le montant celon le type de clients (sex et groupes d'ages)

# %%
type_client = rfm.sex.apply(lambda x: 
                                           "femme" if x=="f" 
                                       else "homme" if x == "m"
                                       else "NAN")
type_clients= type_client.value_counts()
type_clients
# Out:
# femme    4478
# homme    4118
# Name: sex, dtype: int64

# %%
mp.pyplot.pie(x=type_clients,  autopct='%1.1f%%',labels=['Femme','Homme'],explode=[0.1,0.1], colors = ['violet', 'skyblue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x25a091af520>,
#   <matplotlib.patches.Wedge at 0x25a091afc40>],
#  [Text(-0.07888481106565828, 1.1974043538350507, 'Femme'),
#   Text(0.07888469895657158, -1.1974043612207745, 'Homme')],
#  [Text(-0.046016139788300665, 0.6984858730704463, '52.1%'),
#   Text(0.046016074391333414, -0.6984858773787852, '47.9%')])

# %%
sns.set(rc={"figure.figsize":(8,3)},style='darkgrid')
color = ['skyblue','violet']
fig, ax =plt.subplots(1,2)
sns.barplot(data=rfm, x='AgeGroup',y='ca_client',hue = 'sex' ,palette = color,ci=None,ax=ax[0])
sns.barplot(data=rfm, x='AgeGroup',y='frequence', hue = 'sex', palette = color , ci=None,ax=ax[1])
fig.show()

# %% [markdown]
# Pas de difference d'achat visible entre les hommes et les femmes.

# %%
sns.relplot(data=rfm, x="AgeGroup", y="récence", kind="line")

# %% [markdown]
# On peut voir que le groupe d'age 30-45 sont ceux qui ont acheté le plus recement et les 18-30ans il y a le plus longtemps. On observe aussi que la tranche d'age 75-95 posséde les ecarts de recense les plus importante.

# %% [markdown]
# ##### Categorie de produit acheté par tranche d'age.

# %%
dataset2['AgeGroup']= pd.cut(x=dataset2["Age"],bins= [18,30,45,60,75,95], labels=['(18, 30]','(30, 45]','(45, 60]','(60, 75]','(75, 95]'])
dataset2
# Out:
#        id_prod                       date session_id client_id  price  categ  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450   4.99    0.0
# 1       0_1085 2021-09-29 11:14:59.793823    s_97382    c_4450   3.99    0.0
# 2       0_1453 2021-08-27 19:50:46.796939    s_81509    c_4450   7.99    0.0
# 3       0_1405 2021-08-27 20:07:25.878440    s_81509    c_4450   4.99    0.0
# 4       0_1392 2021-12-28 11:45:04.072281   s_141302    c_4450   6.30    0.0
# ...        ...                        ...        ...       ...    ...    ...
# 336811   1_607 2021-09-25 07:26:00.224331    s_95185    c_4786  26.99    1.0
# 336812   1_673 2021-06-01 00:49:49.781631    s_42350    c_2793  12.99    1.0
# 336813  0_2075 2021-10-09 09:03:48.268536   s_102200    c_2793   8.99    0.0
# 336814  0_1692 2021-09-15 19:42:08.596375    s_90430    c_4478  13.36    0.0
# 336815   0_142 2021-09-25 18:07:25.880052    s_95415    c_1232  19.85    0.0
#
#        sex  birth  Age  Année  mois  jour  AgeGroup
# 0        f   1977   45   2021     4    10  (30, 45]
# 1        f   1977   45   2021     9    29  (30, 45]
# 2        f   1977   45   2021     8    27  (30, 45]
# 3        f   1977   45   2021     8    27  (30, 45]
# 4        f   1977   45   2021    12    28  (30, 45]
# ...     ..    ...  ...    ...   ...   ...       ...
# 336811   f   1967   55   2021     9    25  (45, 60]
# 336812   m   1933   89   2021     6     1  (75, 95]
# 336813   m   1933   89   2021    10     9  (75, 95]
# 336814   f   1970   52   2021     9    15  (45, 60]
# 336815   f   1960   62   2021     9    25  (60, 75]
#
# [313651 rows x 13 columns]

# %%
categ_ages= dataset2.groupby(['AgeGroup','categ','sex'])["price"].count()
categ_ages = todataframe(categ_ages)
categ_ages.rename(columns = {'price':'frequence'}, inplace = True)
categ_ages
# Out:
#     AgeGroup  categ sex  frequence
# 0   (18, 30]    0.0   f       3471
# 1   (18, 30]    0.0   m       3210
# 2   (18, 30]    1.0   f       5616
# 3   (18, 30]    1.0   m       5157
# 4   (18, 30]    2.0   f       5981
# 5   (18, 30]    2.0   m       5585
# 6   (30, 45]    0.0   f      60305
# 7   (30, 45]    0.0   m      57195
# 8   (30, 45]    1.0   f      17888
# 9   (30, 45]    1.0   m      16984
# 10  (30, 45]    2.0   f        221
# 11  (30, 45]    2.0   m        225
# 12  (45, 60]    0.0   f      26645
# 13  (45, 60]    0.0   m      24350
# 14  (45, 60]    1.0   f      16597
# 15  (45, 60]    1.0   m      15071
# 16  (45, 60]    2.0   f        252
# 17  (45, 60]    2.0   m        225
# 18  (60, 75]    0.0   f       7743
# 19  (60, 75]    0.0   m       6822
# 20  (60, 75]    1.0   f       9593
# 21  (60, 75]    1.0   m       8186
# 22  (60, 75]    2.0   f        127
# 23  (60, 75]    2.0   m        142
# 24  (75, 95]    0.0   f       2115
# 25  (75, 95]    0.0   m       1746
# 26  (75, 95]    1.0   f       2665
# 27  (75, 95]    1.0   m       2109
# 28  (75, 95]    2.0   f         49
# 29  (75, 95]    2.0   m         28

# %%
sns.set(rc={"figure.figsize":(8,5)},style='whitegrid')
sns.barplot(data=categ_ages , x='AgeGroup',y='frequence',hue = 'categ', palette='Set1', ci= False )
# Out:
# <AxesSubplot:xlabel='AgeGroup', ylabel='frequence'>

# %% [markdown]
# On peut observé que le groupe d'age 30-45 achéte le plus souvant mais principalement des catégories de produits appartenant à la categorie 0 et 1. Les 18-30 achéte moins frequement mais sont parmis ceux qui achéte le plus de la catégorie 2.

# %% [markdown]
# ##### rfm par produit

# %%
data_produit_montant = dataset2[['id_prod','price']]
produit_montant = data_produit_montant .groupby(['id_prod'])["price"].sum()
produit_montant 
produit_montant = todataframe(produit_montant)
produit_montant.rename(columns = {'price':'ca'}, inplace = True)
produit_montant
# Out:
#      id_prod        ca
# 0        0_0   2122.50
# 1        0_1   2604.63
# 2       0_10    197.45
# 3      0_100     41.20
# 4     0_1000   1402.20
# ...      ...       ...
# 3257    2_95    296.97
# 3258    2_96  12360.78
# 3259    2_97    643.96
# 3260    2_98    149.74
# 3261    2_99    169.98
#
# [3262 rows x 2 columns]

# %%
Produit_commande = dataset2.groupby(['id_prod','categ'])['price'].count()
Produit_commande
Produit_commande.to_frame()
Produit_commande= Produit_commande.reset_index()
Produit_commande.rename(columns = {'price':'frequence'}, inplace = True)
Produit_commande
# Out:
#      id_prod  categ  frequence
# 0        0_0    0.0        566
# 1        0_1    0.0        237
# 2       0_10    0.0         11
# 3      0_100    0.0          2
# 4     0_1000    0.0        205
# ...      ...    ...        ...
# 3257    2_95    2.0          3
# 3258    2_96    2.0        258
# 3259    2_97    2.0          4
# 3260    2_98    2.0          1
# 3261    2_99    2.0          2
#
# [3262 rows x 3 columns]

# %%
produit_d= pd.merge(Produit_commande, produit_montant, on='id_prod', how='outer',indicator=True)
produit_d= produit_d.drop('_merge', axis=1)
produit_d
# Out:
#      id_prod  categ  frequence        ca
# 0        0_0    0.0        566   2122.50
# 1        0_1    0.0        237   2604.63
# 2       0_10    0.0         11    197.45
# 3      0_100    0.0          2     41.20
# 4     0_1000    0.0        205   1402.20
# ...      ...    ...        ...       ...
# 3257    2_95    2.0          3    296.97
# 3258    2_96    2.0        258  12360.78
# 3259    2_97    2.0          4    643.96
# 3260    2_98    2.0          1    149.74
# 3261    2_99    2.0          2    169.98
#
# [3262 rows x 4 columns]

# %%
#On fait une new dataframe ou on prend ceux dont a besoin :
data_date =dataset2[['id_prod','date']]
data_produit_last_date = data_date.groupby(['id_prod']).max()

# %%
data_produit_last_date["récence"] =  CalculRecense(data_produit_last_date['date'])
data_produit_last_date.sort_values(by=['récence'])
data_produit_last_date.reset_index()
# Out:
#      id_prod                       date  récence
# 0        0_0 2022-02-28 21:46:33.919651        0
# 1        0_1 2022-02-28 12:36:49.021846        0
# 2       0_10 2022-01-01 18:30:59.958927       58
# 3      0_100 2021-11-06 20:52:21.946694      114
# 4     0_1000 2022-02-28 05:42:37.931101        0
# ...      ...                        ...      ...
# 3257    2_95 2022-02-26 23:30:40.129955        2
# 3258    2_96 2022-02-28 07:11:42.614655        0
# 3259    2_97 2022-02-28 07:31:38.046261        0
# 3260    2_98 2021-03-08 21:10:32.250919      357
# 3261    2_99 2021-11-21 01:53:46.967570       99
#
# [3262 rows x 3 columns]

# %%
rfm_produit= pd.merge(produit_d, data_produit_last_date, on='id_prod', how='outer',indicator=True)
rfm_produit= rfm_produit.drop('_merge', axis=1)
rfm_produit
# Out:
#      id_prod  categ  frequence        ca                       date  récence
# 0        0_0    0.0        566   2122.50 2022-02-28 21:46:33.919651        0
# 1        0_1    0.0        237   2604.63 2022-02-28 12:36:49.021846        0
# 2       0_10    0.0         11    197.45 2022-01-01 18:30:59.958927       58
# 3      0_100    0.0          2     41.20 2021-11-06 20:52:21.946694      114
# 4     0_1000    0.0        205   1402.20 2022-02-28 05:42:37.931101        0
# ...      ...    ...        ...       ...                        ...      ...
# 3257    2_95    2.0          3    296.97 2022-02-26 23:30:40.129955        2
# 3258    2_96    2.0        258  12360.78 2022-02-28 07:11:42.614655        0
# 3259    2_97    2.0          4    643.96 2022-02-28 07:31:38.046261        0
# 3260    2_98    2.0          1    149.74 2021-03-08 21:10:32.250919      357
# 3261    2_99    2.0          2    169.98 2021-11-21 01:53:46.967570       99
#
# [3262 rows x 6 columns]

# %%
categ_prod = rfm_produit['categ'].groupby(rfm_produit['categ'])
nbre_produit_par_categ = categ_prod.describe()
nbre_produit_par_categ= nbre_produit_par_categ.reset_index()
nbres_produit_par_categ= pd.merge(nbre_produit_par_categ, df1, on='categ', how='outer',indicator=True)
nbres_produit_par_categ= nbres_produit_par_categ.drop('_merge', axis=1)
nbres_produit_par_categ= nbres_produit_par_categ.drop('mean', axis=1)
nbres_produit_par_categ= nbres_produit_par_categ.drop('std', axis=1)
nbres_produit_par_categ= nbres_produit_par_categ.drop('min', axis=1)
nbres_produit_par_categ= nbres_produit_par_categ.drop('25%', axis=1)
nbres_produit_par_categ= nbres_produit_par_categ.drop('50%', axis=1)
nbres_produit_par_categ= nbres_produit_par_categ.drop('75%', axis=1)
nbres_produit_par_categ= nbres_produit_par_categ.drop('max', axis=1)
nbres_produit_par_categ
# Out:
#    categ   count          ca
# 0    0.0  2290.0  2078594.02
# 1    1.0   737.0  2101585.34
# 2    2.0   235.0  1183482.61

# %% [markdown]
# Visualisation de la frequence en fonction du  chiffre d'affaire  des produits groupé par cathégorie. La resence est ajouté, plus le point est petit, plus il a été acheté récemment.

# %%
 sns.set(style="darkgrid",rc={'figure.figsize':(8,6)}, palette = "Set1")
nouveau= sns.scatterplot(y="frequence", x="ca", data=rfm_produit, hue=rfm_produit.categ, size = rfm_produit.récence, palette = 'Set1')
nouveau.legend(bbox_to_anchor=(1, 1.1), loc='upper left')

# %% [markdown]
# On peut observé que les produits de type 2 ne sont pas frequemment acheté mais ils rapportent le plus en chiffre d'affaire ( ils sont les plus cher). Les catégories 0 et 1 sont plus fréquemment acheté, on a l'impression qu'ils rapportent moins mais ils sont plus nombreux.

# %% [markdown]
#  Nous avons realisé une heatmap pour observé si il y avait une correlation entre la frequence d'achat, les categories, le chiffre d'affaire et la récences.

# %%
fig, ax = plt.subplots(figsize=(9,6))   
sns.heatmap(rfm_produit.corr(),cmap='Blues',annot=True,ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Plus la valeur est proche de 1 et plus la correlation est probable. On peut observé qu'il y a des correlation possitif plus ou moins forte entre le chiffre d'affaire et la fréquence qui evoluent dans le même sens.
